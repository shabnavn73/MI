# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("data.csv")

# %%
df.columns
# Out:
# Index(['Duration', 'Date', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
plt.plot(df["Pulse"],df["Duration"])
plt.ylabel("Duration")
plt.xlabel("Pulse")
# Out:
# Text(0.5, 0, 'Pulse')

# %%
plt.plot(df["Maxpulse"],df["Duration"])

# %%
plt.plot(df["Calories"],df["Duration"])
plt.plot(df["Pulse"],df["Duration"])
plt.ylabel("Duration")
#plt.legend(["Calories"],["Pulse"])
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4304\2633935239.py:4: UserWarning: Legend does not support 'Calories' instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend(["Calories"],["Pulse"])

# %%
plt.plot(df["Calories"],df["Duration"],marker='o')

# %%
import seaborn as sns

# %%
sns.set_style("whitegrid")
plt.plot(df["Calories"],df["Duration"],marker='o')

# %%
sns.set_style("darkgrid")
plt.plot(df["Calories"],df["Duration"],marker='o')

# %%
plt.scatter(df["Pulse"],df["Duration"],marker='o')
plt.scatter(df["Calories"],df["Duration"],color='hotpink',alpha=0.2)

# %%
plt.bar(df["Pulse"],df["Duration"])
# Out:
# <BarContainer object of 32 artists>

# %%
plt.bar(df["Pulse"],df["Duration"],width=5)
# Out:
# <BarContainer object of 32 artists>

# %%
sns.relplot(data=df,x=df["Pulse"],y=df["Duration"])
